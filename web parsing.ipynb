# %%
! pip3 install requests 
#ставим модуль requests

# %%
# ставим модуль beautifulsoup
! pip3 install beautifulsoup4

# %%
# импортируем модули в тетрадку

import requests as rq

from bs4 import BeautifulSoup

# %%
url = "https://ru.wikipedia.org/wiki/%D0%9F%D0%BE%D1%80%D1%82%D0%B0%D0%BB:%D0%A2%D0%B5%D0%BA%D1%83%D1%89%D0%B8%D0%B5_%D1%81%D0%BE%D0%B1%D1%8B%D1%82%D0%B8%D1%8F"

# %% [markdown]
# В модуле requests есть метод request.get(), который сохраняет ответ сервера на наш реквест. Мы применим его к переменной url, куда сохранен путь к странице.
# Сохраним результат в переменную page

# %%
page = rq.get(url) #res/r/response

page # посмотрим на код ответа, если 200, все хорошо
# Out:
# <Response [200]>

# %%
page.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="ru" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Портал:Текущие события — Википедия</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":[",\\t.","\xa0\\t,"],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","январь","февраль","март","апрель","май","июнь","июль","август","сентябрь","октябрь","ноябрь","декабрь"],"wgRequestId":"3ec28e19-3535-4360-880e-bad5d0195b9b","wgCSPNonce":false,"wgCanonicalNamespace":"Портал","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":100,"wgPageName":"Портал:Текущие_события","wgTitle":"Текущие события","wgCurRevisionId":114604891,"wgRevisionId":114604891,"wgArticleId":1432449,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Порталы по алфавиту","Википедия:Содержание Википедии"],"wgPageContentLanguage":"ru","wgPageContentModel":"wikite
# ...

# %%
soup = BeautifulSoup(page.text, 'html.parser') #сохраним результат в переменную soup

# %%
display(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="ru">
# <head>
# <meta charset="utf-8"/>
# <title>Портал:Текущие события — Википедия</title>
# ...

# %%
print(soup.prettify()) # показывает нашу страницу в красивом виде
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="ru">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Портал:Текущие события — Википедия
#   </title>
#   <script>
# ...

# %%
 soup.find_all('li')
# Out:
# [<li><a class="extiw" href="https://ru.wikinews.org/wiki/%D0%9E%D0%B6%D0%B8%D0%B4%D0%B0%D0%B5%D0%BC%D1%8B%D0%B5_%D1%81%D0%BE%D0%B1%D1%8B%D1%82%D0%B8%D1%8F_10_%D1%84%D0%B5%D0%B2%D1%80%D0%B0%D0%BB%D1%8F_2022_%D0%B3%D0%BE%D0%B4%D0%B0" title="n:Ожидаемые события 10 февраля 2022 года">Ожидаемые события 10 февраля 2022 года</a></li>,
#  <li><a class="extiw" href="https://ru.wikinews.org/wiki/%D0%9E%D0%B6%D0%B8%D0%B4%D0%B0%D0%B5%D0%BC%D1%8B%D0%B5_%D1%81%D0%BE%D0%B1%D1%8B%D1%82%D0%B8%D1%8F_12_%D1%84%D0%B5%D0%B2%D1%80%D0%B0%D0%BB%D1%8F_2022_%D0%B3%D0%BE%D0%B4%D0%B0" title="n:Ожидаемые события 12 февраля 2022 года">Ожидаемые события 12 февраля 2022 года</a></li>,
# ...

# %%
soup.find_all('li')[1]
# Out:
# <li><a class="extiw" href="https://ru.wikinews.org/wiki/%D0%9E%D0%B6%D0%B8%D0%B4%D0%B0%D0%B5%D0%BC%D1%8B%D0%B5_%D1%81%D0%BE%D0%B1%D1%8B%D1%82%D0%B8%D1%8F_12_%D1%84%D0%B5%D0%B2%D1%80%D0%B0%D0%BB%D1%8F_2022_%D0%B3%D0%BE%D0%B4%D0%B0" title="n:Ожидаемые события 12 февраля 2022 года">Ожидаемые события 12 февраля 2022 года</a></li>

# %% [markdown]
# метод .get_text() позволит вытащить текст из элемента:

# %%
for i in range(50):
    print(soup.find_all('li')[i].get_text())
# Out:
# Ожидаемые события 10 февраля 2022 года
# Ожидаемые события 12 февраля 2022 года
# Умер известный советский и российский эсперантист Анатолий Гончаров
# В Петербурге ребёнок погиб под колёсами электрички
# Выброс лавы и пепла отмечен на вулкане Этна
# Дарио Колонья готовится к прощальной индивидуальной гонке
# Воздушные суда на NAIS
# В Сомали произошли два взрыва за один день
# Лео Фест придёт в пять городов России
# Выставка и форум гражданской авиации NAIS: фоторепортаж и церемония награждения
# Илья Яшин создал петицию за отставку Рамзана Кадырова
# В двух разделах Википедии стартовал конкурс «Мир университетов»
# Алёхин, Иван Тихонович (85)
# Баджаж, Рахул[en] (83)
# Ваделль-и-Феррер, Антони (49)
# Кириенко, Зинаида Михайловна (88)
# Конгантиев, Молдомуса Ташболотович (63)
# Лепик, Юло Рудольфович (100)
# Чумбуридзе, Зураб Галактионович (95)
# Аддай II (74)
# Ахвледиани, Ломер Бидзинович (87)
# Датунашвили, Илья Ильич (84)
# Дегоши, Люсьен (84)
# Категория «Текущие события»
# ...
